# %% [markdown]
# ![image.png](attachment:image.png)
# In the previous week, you examined multivariate analysis using heatmaps, bubble plots, principal component analysis, and linear regression. This time, you will use these methods on your own datasets.

# %% [markdown]
# ## Multivariate Analysis 2
# There will be no full lesson this week, except for the assigned reading. You are expected to meet with your groups to discuss your homework assignments, peer feedback, and ongoing project work.
#
# We encourage you to take time this week to:
# - Read and reflect on the text and questions below
# - Complete this week’s homework activity
# - Review your notes from previous weeks and the feedback from your peers, and make edits to your final project
# - Meet with your group to discuss ongoing work and learn from each other
# - Prepare any questions you may have for the instructors ahead of the live session
#
# Think About It
# - How can ‘super categories’ enhance comprehension in a data visualization?
# - What strategies can you use to create effective visual hierarchies?
# - Why should you prioritize simplicity in a visualization?
